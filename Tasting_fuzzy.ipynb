# %% [markdown]
# <a href="https://colab.research.google.com/github/Iambinhh/Tasting_fuzzy/blob/main/Tasting_fuzzy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl 


taste = ctrl.Antecedent(np.arange(0,11,0.25),'taste')


environment = ctrl.Antecedent(np.arange(0,11,0.25),'environment')
budget = ctrl.Antecedent(np.arange(1,10,0.25),'budget')
user_review = ctrl.Antecedent(np.arange(0,6,0.25),'user_review')
location = ctrl.Antecedent(np.arange(0,4,0.1),'location')

preference= ctrl.Consequent(np.arange(0,10,0.25),'preference')

taste['less']=fuzz.gaussmf(taste.universe,0,2)
taste['medium']=fuzz.gaussmf(taste.universe,5,2)
taste['high']=fuzz.gaussmf(taste.universe,10,2)

environment['less']=fuzz.gaussmf(environment.universe,0,1)
environment['medium']=fuzz.gaussmf(environment.universe,5,0.25)
environment['high']=fuzz.gaussmf(environment.universe,10,1)

budget['less preferred']=fuzz.gaussmf(budget.universe,7.5,1)
budget['preferred']=fuzz.gaussmf(budget.universe,4.5,1)
budget['more preferred']=fuzz.gaussmf(budget.universe,1.5,1)

user_review['more preferred']=fuzz.gaussmf(user_review.universe,4.5,1)
user_review['preferred']=fuzz.gaussmf(user_review.universe,2.5,1)
user_review['less preferred']=fuzz.gaussmf(user_review.universe,0.5,1)

location['closer']=fuzz.gaussmf(location.universe,0.5,0.5)
location['near']=fuzz.gaussmf(location.universe,1.5,0.5)
location['far']=fuzz.gaussmf(location.universe,2.5,0.5)

preference['level1']=fuzz.trimf(preference.universe,[0,1.5,3])
preference['level2']=fuzz.trimf(preference.universe,[1.5,3,4.5])
preference['level3']=fuzz.trimf(preference.universe,[3,4.5,6])
preference['level4']=fuzz.trimf(preference.universe,[4.5,6,7.5])
preference['level5']=fuzz.trimf(preference.universe,[6,7.5,9])

rule1 = ctrl.Rule(taste['less']&environment['less']&budget['less preferred']&user_review['less preferred']&location['far'],preference['level1'])
rule2 = ctrl.Rule(taste['less']&environment['less']&budget['less preferred']&user_review['less preferred']&location['near'],preference['level1'])
rule3 = ctrl.Rule(taste['less']&environment['less']&budget['less preferred']&user_review['less preferred']&location['closer'],preference['level1'])
rule4 = ctrl.Rule(taste['less']&environment['less']&budget['less preferred']&user_review['preferred']&location['far'],preference['level1'])
rule5 = ctrl.Rule(taste['less']&environment['less']&budget['less preferred']&user_review['preferred']&location['near'],preference['level1'])
rule6 = ctrl.Rule(taste['less']&environment['less']&budget['less preferred']&user_review['preferred']&location['closer'],preference['level1'])
rule7 = ctrl.Rule(taste['less']&environment['less']&budget['less preferred']&user_review['more preferred']&location['far'],preference['level1'])
rule8 = ctrl.Rule(taste['less']&environment['less']&budget['less preferred']&user_review['more preferred']&location['near'],preference['level1'])
rule9 = ctrl.Rule(taste['less']&environment['less']&budget['less preferred']&user_review['more preferred']&location['closer'],preference['level2'])
rule10 = ctrl.Rule(taste['less']&environment['less']&budget['preferred']&user_review['less preferred']&location['far'],preference['level1'])
rule11 = ctrl.Rule(taste['less']&environment['less']&budget['preferred']&user_review['less preferred']&location['near'],preference['level1'])
rule12 = ctrl.Rule(taste['less']&environment['less']&budget['preferred']&user_review['less preferred']&location['closer'],preference['level1'])
rule13 = ctrl.Rule(taste['less']&environment['less']&budget['preferred']&user_review['preferred']&location['far'],preference['level1'])
rule14 = ctrl.Rule(taste['less']&environment['less']&budget['preferred']&user_review['preferred']&location['near'],preference['level1'])
rule15 = ctrl.Rule(taste['less']&environment['less']&budget['preferred']&user_review['preferred']&location['closer'],preference['level2'])
rule16 = ctrl.Rule(taste['less']&environment['less']&budget['preferred']&user_review['more preferred']&location['far'],preference['level2'])
rule17 = ctrl.Rule(taste['less']&environment['less']&budget['preferred']&user_review['more preferred']&location['near'],preference['level2'])
rule18 = ctrl.Rule(taste['less']&environment['less']&budget['preferred']&user_review['more preferred']&location['closer'],preference['level2'])
rule19 = ctrl.Rule(taste['less']&environment['less']&budget['more preferred']&user_review['less preferred']&location['far'],preference['level2'])
rule20 = ctrl.Rule(taste['less']&environment['less']&budget['more preferred']&user_review['less preferred']&location['near'],preference['level2'])
rule21 = ctrl.Rule(taste['less']&environment['less']&budget['more preferred']&user_review['less preferred']&location['closer'],preference['level2'])
rule22 = ctrl.Rule(taste['less']&environment['less']&budget['more preferred']&user_review['preferred']&location['far'],preference['level2'])
rule23 = ctrl.Rule(taste['less']&environment['less']&budget['more preferred']&user_review['preferred']&location['near'],preference['level2'])
rule24 = ctrl.Rule(taste['less']&environment['less']&budget['more preferred']&user_review['preferred']&location['closer'],preference['level2'])
rule25 = ctrl.Rule(taste['less']&environment['less']&budget['more preferred']&user_review['more preferred']&location['far'],preference['level2'])
rule26 = ctrl.Rule(taste['less']&environment['less']&budget['more preferred']&user_review['more preferred']&location['near'],preference['level2'])
rule27 = ctrl.Rule(taste['less']&environment['less']&budget['more preferred']&user_review['more preferred']&location['closer'],preference['level2'])
rule28 = ctrl.Rule(taste['less']&environment['medium']&budget['less preferred']&user_review['less preferred']&location['far'],preference['level1'])
rule29 = ctrl.Rule(taste['less']&environment['medium']&budget['less preferred']&user_review['less preferred']&location['near'],preference['level1'])
rule30 = ctrl.Rule(taste['less']&environment['medium']&budget['less preferred']&user_review['less preferred']&location['closer'],preference['level2'])
rule31 = ctrl.Rule(taste['less']&environment['medium']&budget['less preferred']&user_review['preferred']&location['far'],preference['level1'])
rule32 = ctrl.Rule(taste['less']&environment['medium']&budget['less preferred']&user_review['preferred']&location['near'],preference['level1'])
rule33 = ctrl.Rule(taste['less']&environment['medium']&budget['less preferred']&user_review['preferred']&location['closer'],preference['level1'])
rule34 = ctrl.Rule(taste['less']&environment['medium']&budget['less preferred']&user_review['more preferred']&location['far'],preference['level2'])
rule35 = ctrl.Rule(taste['less']&environment['medium']&budget['less preferred']&user_review['more preferred']&location['near'],preference['level2'])
rule36 = ctrl.Rule(taste['less']&environment['medium']&budget['less preferred']&user_review['more preferred']&location['closer'],preference['level2'])
rule37 = ctrl.Rule(taste['less']&environment['medium']&budget['preferred']&user_review['less preferred']&location['far'],preference['level1'])
rule38 = ctrl.Rule(taste['less']&environment['medium']&budget['preferred']&user_review['less preferred']&location['near'],preference['level1'])
rule39 = ctrl.Rule(taste['less']&environment['medium']&budget['preferred']&user_review['less preferred']&location['closer'],preference['level1'])
rule40 = ctrl.Rule(taste['less']&environment['medium']&budget['preferred']&user_review['preferred']&location['far'],preference['level2'])
rule41 = ctrl.Rule(taste['less']&environment['medium']&budget['preferred']&user_review['preferred']&location['near'],preference['level2'])
rule42 = ctrl.Rule(taste['less']&environment['medium']&budget['preferred']&user_review['preferred']&location['closer'],preference['level2'])
rule43 = ctrl.Rule(taste['less']&environment['medium']&budget['preferred']&user_review['more preferred']&location['far'],preference['level2'])
rule44 = ctrl.Rule(taste['less']&environment['medium']&budget['preferred']&user_review['more preferred']&location['near'],preference['level2'])
rule45 = ctrl.Rule(taste['less']&environment['medium']&budget['preferred']&user_review['more preferred']&location['closer'],preference['level2'])
rule46 = ctrl.Rule(taste['less']&environment['medium']&budget['more preferred']&user_review['less preferred']&location['far'],preference['level2'])
rule47 = ctrl.Rule(taste['less']&environment['medium']&budget['more preferred']&user_review['less preferred']&location['near'],preference['level2'])
rule48 = ctrl.Rule(taste['less']&environment['medium']&budget['more preferred']&user_review['less preferred']&location['closer'],preference['level2'])
rule49 = ctrl.Rule(taste['less']&environment['medium']&budget['more preferred']&user_review['preferred']&location['far'],preference['level1'])
rule50 = ctrl.Rule(taste['less']&environment['medium']&budget['more preferred']&user_review['preferred']&location['near'],preference['level1'])
rule51 = ctrl.Rule(taste['less']&environment['medium']&budget['more preferred']&user_review['preferred']&location['closer'],preference['level1'])
rule52 = ctrl.Rule(taste['less']&environment['medium']&budget['more preferred']&user_review['more preferred']&location['far'],preference['level3'])
rule53 = ctrl.Rule(taste['less']&environment['medium']&budget['more preferred']&user_review['more preferred']&location['near'],preference['level3'])
rule54 = ctrl.Rule(taste['less']&environment['medium']&budget['more preferred']&user_review['more preferred']&location['closer'],preference['level3'])
rule55 = ctrl.Rule(taste['less']&environment['high']&budget['less preferred']&user_review['less preferred']&location['far'],preference['level1'])
rule56 = ctrl.Rule(taste['less']&environment['high']&budget['less preferred']&user_review['less preferred']&location['near'],preference['level2'])
rule57 = ctrl.Rule(taste['less']&environment['high']&budget['less preferred']&user_review['less preferred']&location['closer'],preference['level2'])
rule58 = ctrl.Rule(taste['less']&environment['high']&budget['less preferred']&user_review['preferred']&location['far'],preference['level1'])
rule59 = ctrl.Rule(taste['less']&environment['high']&budget['less preferred']&user_review['preferred']&location['near'],preference['level2'])
rule60 = ctrl.Rule(taste['less']&environment['high']&budget['less preferred']&user_review['preferred']&location['closer'],preference['level2'])
rule61 = ctrl.Rule(taste['less']&environment['high']&budget['less preferred']&user_review['more preferred']&location['far'],preference['level3'])
rule62 = ctrl.Rule(taste['less']&environment['high']&budget['less preferred']&user_review['more preferred']&location['near'],preference['level3'])
rule63 = ctrl.Rule(taste['less']&environment['high']&budget['less preferred']&user_review['more preferred']&location['closer'],preference['level3'])
rule64 = ctrl.Rule(taste['less']&environment['high']&budget['preferred']&user_review['less preferred']&location['far'],preference['level2'])
rule65 = ctrl.Rule(taste['less']&environment['high']&budget['preferred']&user_review['less preferred']&location['near'],preference['level2'])
rule66 = ctrl.Rule(taste['less']&environment['high']&budget['preferred']&user_review['less preferred']&location['closer'],preference['level2'])
rule67 = ctrl.Rule(taste['less']&environment['high']&budget['preferred']&user_review['preferred']&location['far'],preference['level2'])
rule68 = ctrl.Rule(taste['less']&environment['high']&budget['preferred']&user_review['preferred']&location['near'],preference['level2'])
rule69 = ctrl.Rule(taste['less']&environment['high']&budget['preferred']&user_review['preferred']&location['closer'],preference['level2'])
rule70 = ctrl.Rule(taste['less']&environment['high']&budget['preferred']&user_review['more preferred']&location['far'],preference['level3'])
rule71 = ctrl.Rule(taste['less']&environment['high']&budget['preferred']&user_review['more preferred']&location['near'],preference['level3'])
rule72 = ctrl.Rule(taste['less']&environment['high']&budget['preferred']&user_review['more preferred']&location['closer'],preference['level3'])
rule73 = ctrl.Rule(taste['less']&environment['high']&budget['more preferred']&user_review['less preferred']&location['far'],preference['level3'])
rule74 = ctrl.Rule(taste['less']&environment['high']&budget['more preferred']&user_review['less preferred']&location['near'],preference['level3'])
rule75 = ctrl.Rule(taste['less']&environment['high']&budget['more preferred']&user_review['less preferred']&location['closer'],preference['level3'])
rule76 = ctrl.Rule(taste['less']&environment['high']&budget['more preferred']&user_review['preferred']&location['far'],preference['level3'])
rule77 = ctrl.Rule(taste['less']&environment['high']&budget['more preferred']&user_review['preferred']&location['near'],preference['level3'])
rule78 = ctrl.Rule(taste['less']&environment['high']&budget['more preferred']&user_review['preferred']&location['closer'],preference['level3'])
rule79 = ctrl.Rule(taste['less']&environment['high']&budget['more preferred']&user_review['more preferred']&location['far'],preference['level4'])
rule80 = ctrl.Rule(taste['less']&environment['high']&budget['more preferred']&user_review['more preferred']&location['near'],preference['level4'])
rule81 = ctrl.Rule(taste['less']&environment['high']&budget['more preferred']&user_review['more preferred']&location['closer'],preference['level4'])
rule82 = ctrl.Rule(taste['medium']&environment['less']&budget['less preferred']&user_review['less preferred']&location['far'],preference['level1'])
rule83 = ctrl.Rule(taste['medium']&environment['less']&budget['less preferred']&user_review['less preferred']&location['near'],preference['level1'])
rule84 = ctrl.Rule(taste['medium']&environment['less']&budget['less preferred']&user_review['less preferred']&location['closer'],preference['level2'])
rule85 = ctrl.Rule(taste['medium']&environment['less']&budget['less preferred']&user_review['preferred']&location['far'],preference['level1'])
rule86 = ctrl.Rule(taste['medium']&environment['less']&budget['less preferred']&user_review['preferred']&location['near'],preference['level1'])
rule87 = ctrl.Rule(taste['medium']&environment['less']&budget['less preferred']&user_review['preferred']&location['closer'],preference['level2'])
rule88 = ctrl.Rule(taste['medium']&environment['less']&budget['less preferred']&user_review['more preferred']&location['far'],preference['level1'])
rule89 = ctrl.Rule(taste['medium']&environment['less']&budget['less preferred']&user_review['more preferred']&location['near'],preference['level2'])
rule90 = ctrl.Rule(taste['medium']&environment['less']&budget['less preferred']&user_review['more preferred']&location['closer'],preference['level3'])
rule91 = ctrl.Rule(taste['medium']&environment['less']&budget['preferred']&user_review['less preferred']&location['far'],preference['level1'])
rule92 = ctrl.Rule(taste['medium']&environment['less']&budget['preferred']&user_review['less preferred']&location['near'],preference['level2'])
rule93 = ctrl.Rule(taste['medium']&environment['less']&budget['preferred']&user_review['less preferred']&location['closer'],preference['level2'])
rule94 = ctrl.Rule(taste['medium']&environment['less']&budget['preferred']&user_review['preferred']&location['far'],preference['level2'])
rule95 = ctrl.Rule(taste['medium']&environment['less']&budget['preferred']&user_review['preferred']&location['near'],preference['level2'])
rule96 = ctrl.Rule(taste['medium']&environment['less']&budget['preferred']&user_review['preferred']&location['closer'],preference['level2'])
rule97 = ctrl.Rule(taste['medium']&environment['less']&budget['preferred']&user_review['more preferred']&location['far'],preference['level3'])
rule98 = ctrl.Rule(taste['medium']&environment['less']&budget['preferred']&user_review['more preferred']&location['near'],preference['level3'])
rule99 = ctrl.Rule(taste['medium']&environment['less']&budget['preferred']&user_review['more preferred']&location['closer'],preference['level3'])
rule100 = ctrl.Rule(taste['medium']&environment['less']&budget['more preferred']&user_review['less preferred']&location['far'],preference['level2'])
rule101 = ctrl.Rule(taste['medium']&environment['less']&budget['more preferred']&user_review['less preferred']&location['near'],preference['level2'])
rule102 = ctrl.Rule(taste['medium']&environment['less']&budget['more preferred']&user_review['less preferred']&location['closer'],preference['level3'])
rule103 = ctrl.Rule(taste['medium']&environment['less']&budget['more preferred']&user_review['preferred']&location['far'],preference['level3'])
rule104 = ctrl.Rule(taste['medium']&environment['less']&budget['more preferred']&user_review['preferred']&location['near'],preference['level3'])
rule105 = ctrl.Rule(taste['medium']&environment['less']&budget['more preferred']&user_review['preferred']&location['closer'],preference['level4'])
rule106 = ctrl.Rule(taste['medium']&environment['less']&budget['more preferred']&user_review['more preferred']&location['far'],preference['level4'])
rule107 = ctrl.Rule(taste['medium']&environment['less']&budget['more preferred']&user_review['more preferred']&location['near'],preference['level4'])
rule108 = ctrl.Rule(taste['medium']&environment['less']&budget['more preferred']&user_review['more preferred']&location['closer'],preference['level4'])
rule109 = ctrl.Rule(taste['medium']&environment['medium']&budget['less preferred']&user_review['less preferred']&location['far'],preference['level2'])
rule110 = ctrl.Rule(taste['medium']&environment['medium']&budget['less preferred']&user_review['less preferred']&location['near'],preference['level2'])
rule111 = ctrl.Rule(taste['medium']&environment['medium']&budget['less preferred']&user_review['less preferred']&location['closer'],preference['level2'])
rule112 = ctrl.Rule(taste['medium']&environment['medium']&budget['less preferred']&user_review['preferred']&location['far'],preference['level2'])
rule113 = ctrl.Rule(taste['medium']&environment['medium']&budget['less preferred']&user_review['preferred']&location['near'],preference['level2'])
rule114 = ctrl.Rule(taste['medium']&environment['medium']&budget['less preferred']&user_review['preferred']&location['closer'],preference['level3'])
rule115 = ctrl.Rule(taste['medium']&environment['medium']&budget['less preferred']&user_review['more preferred']&location['far'],preference['level3'])
rule116 = ctrl.Rule(taste['medium']&environment['medium']&budget['less preferred']&user_review['more preferred']&location['near'],preference['level3'])
rule117 = ctrl.Rule(taste['medium']&environment['medium']&budget['less preferred']&user_review['more preferred']&location['closer'],preference['level3'])
rule118 = ctrl.Rule(taste['medium']&environment['medium']&budget['preferred']&user_review['less preferred']&location['far'],preference['level2'])
rule119 = ctrl.Rule(taste['medium']&environment['medium']&budget['preferred']&user_review['less preferred']&location['near'],preference['level2'])
rule120 = ctrl.Rule(taste['medium']&environment['medium']&budget['preferred']&user_review['less preferred']&location['closer'],preference['level3'])
rule121 = ctrl.Rule(taste['medium']&environment['medium']&budget['preferred']&user_review['preferred']&location['far'],preference['level3'])
rule122 = ctrl.Rule(taste['medium']&environment['medium']&budget['preferred']&user_review['preferred']&location['near'],preference['level3'])
rule123 = ctrl.Rule(taste['medium']&environment['medium']&budget['preferred']&user_review['preferred']&location['closer'],preference['level3'])
rule124 = ctrl.Rule(taste['medium']&environment['medium']&budget['preferred']&user_review['more preferred']&location['far'],preference['level4'])
rule125 = ctrl.Rule(taste['medium']&environment['medium']&budget['preferred']&user_review['more preferred']&location['near'],preference['level4'])
rule126 = ctrl.Rule(taste['medium']&environment['medium']&budget['preferred']&user_review['more preferred']&location['closer'],preference['level4'])
rule127 = ctrl.Rule(taste['medium']&environment['medium']&budget['more preferred']&user_review['less preferred']&location['far'],preference['level4'])
rule128 = ctrl.Rule(taste['medium']&environment['medium']&budget['more preferred']&user_review['less preferred']&location['near'],preference['level4'])
rule129 = ctrl.Rule(taste['medium']&environment['medium']&budget['more preferred']&user_review['less preferred']&location['closer'],preference['level4'])
rule130 = ctrl.Rule(taste['medium']&environment['medium']&budget['more preferred']&user_review['preferred']&location['far'],preference['level4'])
rule131 = ctrl.Rule(taste['medium']&environment['medium']&budget['more preferred']&user_review['preferred']&location['near'],preference['level4'])
rule132 = ctrl.Rule(taste['medium']&environment['medium']&budget['more preferred']&user_review['preferred']&location['closer'],preference['level4'])
rule133 = ctrl.Rule(taste['medium']&environment['medium']&budget['more preferred']&user_review['more preferred']&location['far'],preference['level4'])
rule134 = ctrl.Rule(taste['medium']&environment['medium']&budget['more preferred']&user_review['more preferred']&location['near'],preference['level4'])
rule135 = ctrl.Rule(taste['medium']&environment['medium']&budget['more preferred']&user_review['more preferred']&location['closer'],preference['level4'])
rule136 = ctrl.Rule(taste['medium']&environment['high']&budget['less preferred']&user_review['less preferred']&location['far'],preference['level2'])
rule137 = ctrl.Rule(taste['medium']&environment['high']&budget['less preferred']&user_review['less preferred']&location['near'],preference['level2'])
rule138 = ctrl.Rule(taste['medium']&environment['high']&budget['less preferred']&user_review['less preferred']&location['closer'],preference['level2'])
rule139 = ctrl.Rule(taste['medium']&environment['high']&budget['less preferred']&user_review['preferred']&location['far'],preference['level2'])
rule140 = ctrl.Rule(taste['medium']&environment['high']&budget['less preferred']&user_review['preferred']&location['near'],preference['level2'])
rule141 = ctrl.Rule(taste['medium']&environment['high']&budget['less preferred']&user_review['preferred']&location['closer'],preference['level2'])
rule142 = ctrl.Rule(taste['medium']&environment['high']&budget['less preferred']&user_review['more preferred']&location['far'],preference['level3'])
rule143 = ctrl.Rule(taste['medium']&environment['high']&budget['less preferred']&user_review['more preferred']&location['near'],preference['level3'])
rule144 = ctrl.Rule(taste['medium']&environment['high']&budget['less preferred']&user_review['more preferred']&location['closer'],preference['level3'])
rule145 = ctrl.Rule(taste['medium']&environment['high']&budget['preferred']&user_review['less preferred']&location['far'],preference['level3'])
rule146 = ctrl.Rule(taste['medium']&environment['high']&budget['preferred']&user_review['less preferred']&location['near'],preference['level3'])
rule147 = ctrl.Rule(taste['medium']&environment['high']&budget['preferred']&user_review['less preferred']&location['closer'],preference['level3'])
rule148 = ctrl.Rule(taste['medium']&environment['high']&budget['preferred']&user_review['preferred']&location['far'],preference['level3'])
rule149 = ctrl.Rule(taste['medium']&environment['high']&budget['preferred']&user_review['preferred']&location['near'],preference['level3'])
rule150 = ctrl.Rule(taste['medium']&environment['high']&budget['preferred']&user_review['preferred']&location['closer'],preference['level3'])
rule151 = ctrl.Rule(taste['medium']&environment['high']&budget['preferred']&user_review['more preferred']&location['far'],preference['level3'])
rule152 = ctrl.Rule(taste['medium']&environment['high']&budget['preferred']&user_review['more preferred']&location['near'],preference['level4'])
rule153 = ctrl.Rule(taste['medium']&environment['high']&budget['preferred']&user_review['more preferred']&location['closer'],preference['level4'])
rule154 = ctrl.Rule(taste['medium']&environment['high']&budget['more preferred']&user_review['less preferred']&location['far'],preference['level4'])
rule155 = ctrl.Rule(taste['medium']&environment['high']&budget['more preferred']&user_review['less preferred']&location['near'],preference['level4'])
rule156 = ctrl.Rule(taste['medium']&environment['high']&budget['more preferred']&user_review['less preferred']&location['closer'],preference['level4'])
rule157 = ctrl.Rule(taste['medium']&environment['high']&budget['more preferred']&user_review['preferred']&location['far'],preference['level4'])
rule158 = ctrl.Rule(taste['medium']&environment['high']&budget['more preferred']&user_review['preferred']&location['near'],preference['level4'])
rule159 = ctrl.Rule(taste['medium']&environment['high']&budget['more preferred']&user_review['preferred']&location['closer'],preference['level4'])
rule160 = ctrl.Rule(taste['medium']&environment['high']&budget['more preferred']&user_review['more preferred']&location['far'],preference['level5'])
rule161 = ctrl.Rule(taste['medium']&environment['high']&budget['more preferred']&user_review['more preferred']&location['near'],preference['level5'])
rule162 = ctrl.Rule(taste['medium']&environment['high']&budget['more preferred']&user_review['more preferred']&location['closer'],preference['level5'])
rule163 = ctrl.Rule(taste['high']&environment['less']&budget['less preferred']&user_review['less preferred']&location['far'],preference['level1'])
rule164 = ctrl.Rule(taste['high']&environment['less']&budget['less preferred']&user_review['less preferred']&location['near'],preference['level1'])
rule165 = ctrl.Rule(taste['high']&environment['less']&budget['less preferred']&user_review['less preferred']&location['closer'],preference['level2'])
rule166 = ctrl.Rule(taste['high']&environment['less']&budget['less preferred']&user_review['preferred']&location['far'],preference['level2'])
rule167 = ctrl.Rule(taste['high']&environment['less']&budget['less preferred']&user_review['preferred']&location['near'],preference['level2'])
rule168 = ctrl.Rule(taste['high']&environment['less']&budget['less preferred']&user_review['preferred']&location['closer'],preference['level2'])
rule169 = ctrl.Rule(taste['high']&environment['less']&budget['less preferred']&user_review['more preferred']&location['far'],preference['level3'])
rule170 = ctrl.Rule(taste['high']&environment['less']&budget['less preferred']&user_review['more preferred']&location['near'],preference['level3'])
rule171 = ctrl.Rule(taste['high']&environment['less']&budget['less preferred']&user_review['more preferred']&location['closer'],preference['level3'])
rule172 = ctrl.Rule(taste['high']&environment['less']&budget['preferred']&user_review['less preferred']&location['far'],preference['level2'])
rule173 = ctrl.Rule(taste['high']&environment['less']&budget['preferred']&user_review['less preferred']&location['near'],preference['level2'])
rule174 = ctrl.Rule(taste['high']&environment['less']&budget['preferred']&user_review['less preferred']&location['closer'],preference['level2'])
rule175 = ctrl.Rule(taste['high']&environment['less']&budget['preferred']&user_review['preferred']&location['far'],preference['level2'])
rule176 = ctrl.Rule(taste['high']&environment['less']&budget['preferred']&user_review['preferred']&location['near'],preference['level2'])
rule177 = ctrl.Rule(taste['high']&environment['less']&budget['preferred']&user_review['preferred']&location['closer'],preference['level3'])
rule178 = ctrl.Rule(taste['high']&environment['less']&budget['preferred']&user_review['more preferred']&location['far'],preference['level3'])
rule179 = ctrl.Rule(taste['high']&environment['less']&budget['preferred']&user_review['more preferred']&location['near'],preference['level3'])
rule180 = ctrl.Rule(taste['high']&environment['less']&budget['preferred']&user_review['more preferred']&location['closer'],preference['level3'])
rule181 = ctrl.Rule(taste['high']&environment['less']&budget['more preferred']&user_review['less preferred']&location['far'],preference['level3'])
rule182 = ctrl.Rule(taste['high']&environment['less']&budget['more preferred']&user_review['less preferred']&location['near'],preference['level3'])
rule183 = ctrl.Rule(taste['high']&environment['less']&budget['more preferred']&user_review['less preferred']&location['closer'],preference['level3'])
rule184 = ctrl.Rule(taste['high']&environment['less']&budget['more preferred']&user_review['preferred']&location['far'],preference['level3'])
rule185 = ctrl.Rule(taste['high']&environment['less']&budget['more preferred']&user_review['preferred']&location['near'],preference['level3'])
rule186 = ctrl.Rule(taste['high']&environment['less']&budget['more preferred']&user_review['preferred']&location['closer'],preference['level3'])
rule187 = ctrl.Rule(taste['high']&environment['less']&budget['more preferred']&user_review['more preferred']&location['far'],preference['level4'])
rule188 = ctrl.Rule(taste['high']&environment['less']&budget['more preferred']&user_review['more preferred']&location['near'],preference['level4'])
rule189 = ctrl.Rule(taste['high']&environment['less']&budget['more preferred']&user_review['more preferred']&location['closer'],preference['level4'])
rule190 = ctrl.Rule(taste['high']&environment['medium']&budget['less preferred']&user_review['less preferred']&location['far'],preference['level2'])
rule191 = ctrl.Rule(taste['high']&environment['medium']&budget['less preferred']&user_review['less preferred']&location['near'],preference['level2'])
rule192 = ctrl.Rule(taste['high']&environment['medium']&budget['less preferred']&user_review['less preferred']&location['closer'],preference['level2'])
rule193 = ctrl.Rule(taste['high']&environment['medium']&budget['less preferred']&user_review['preferred']&location['far'],preference['level2'])
rule194 = ctrl.Rule(taste['high']&environment['medium']&budget['less preferred']&user_review['preferred']&location['near'],preference['level2'])
rule195 = ctrl.Rule(taste['high']&environment['medium']&budget['less preferred']&user_review['preferred']&location['closer'],preference['level2'])
rule196 = ctrl.Rule(taste['high']&environment['medium']&budget['less preferred']&user_review['more preferred']&location['far'],preference['level2'])
rule197 = ctrl.Rule(taste['high']&environment['medium']&budget['less preferred']&user_review['more preferred']&location['near'],preference['level2'])
rule198 = ctrl.Rule(taste['high']&environment['medium']&budget['less preferred']&user_review['more preferred']&location['closer'],preference['level2'])
rule199 = ctrl.Rule(taste['high']&environment['medium']&budget['preferred']&user_review['less preferred']&location['far'],preference['level3'])
rule200 = ctrl.Rule(taste['high']&environment['medium']&budget['preferred']&user_review['less preferred']&location['near'],preference['level3'])
rule201 = ctrl.Rule(taste['high']&environment['medium']&budget['preferred']&user_review['less preferred']&location['closer'],preference['level3'])
rule202 = ctrl.Rule(taste['high']&environment['medium']&budget['preferred']&user_review['preferred']&location['far'],preference['level3'])
rule203 = ctrl.Rule(taste['high']&environment['medium']&budget['preferred']&user_review['preferred']&location['near'],preference['level3'])
rule204 = ctrl.Rule(taste['high']&environment['medium']&budget['preferred']&user_review['preferred']&location['closer'],preference['level3'])
rule205 = ctrl.Rule(taste['high']&environment['medium']&budget['preferred']&user_review['more preferred']&location['far'],preference['level4'])
rule206 = ctrl.Rule(taste['high']&environment['medium']&budget['preferred']&user_review['more preferred']&location['near'],preference['level4'])
rule207 = ctrl.Rule(taste['high']&environment['medium']&budget['preferred']&user_review['more preferred']&location['closer'],preference['level4'])
rule208 = ctrl.Rule(taste['high']&environment['medium']&budget['more preferred']&user_review['less preferred']&location['far'],preference['level4'])
rule209 = ctrl.Rule(taste['high']&environment['medium']&budget['more preferred']&user_review['less preferred']&location['near'],preference['level4'])
rule210 = ctrl.Rule(taste['high']&environment['medium']&budget['more preferred']&user_review['less preferred']&location['closer'],preference['level4'])
rule211 = ctrl.Rule(taste['high']&environment['medium']&budget['more preferred']&user_review['preferred']&location['far'],preference['level4'])
rule212 = ctrl.Rule(taste['high']&environment['medium']&budget['more preferred']&user_review['preferred']&location['near'],preference['level4'])
rule213 = ctrl.Rule(taste['high']&environment['medium']&budget['more preferred']&user_review['preferred']&location['closer'],preference['level4'])
rule214 = ctrl.Rule(taste['high']&environment['medium']&budget['more preferred']&user_review['more preferred']&location['far'],preference['level5'])
rule215 = ctrl.Rule(taste['high']&environment['medium']&budget['more preferred']&user_review['more preferred']&location['near'],preference['level5'])
rule216 = ctrl.Rule(taste['high']&environment['medium']&budget['more preferred']&user_review['more preferred']&location['closer'],preference['level5'])
rule217 = ctrl.Rule(taste['high']&environment['high']&budget['less preferred']&user_review['less preferred']&location['far'],preference['level3'])
rule218 = ctrl.Rule(taste['high']&environment['high']&budget['less preferred']&user_review['less preferred']&location['near'],preference['level3'])
rule219 = ctrl.Rule(taste['high']&environment['high']&budget['less preferred']&user_review['less preferred']&location['closer'],preference['level3'])
rule220 = ctrl.Rule(taste['high']&environment['high']&budget['less preferred']&user_review['preferred']&location['far'],preference['level3'])
rule221 = ctrl.Rule(taste['high']&environment['high']&budget['less preferred']&user_review['preferred']&location['near'],preference['level3'])
rule222 = ctrl.Rule(taste['high']&environment['high']&budget['less preferred']&user_review['preferred']&location['closer'],preference['level3'])
rule223 = ctrl.Rule(taste['high']&environment['high']&budget['less preferred']&user_review['more preferred']&location['far'],preference['level3'])
rule224 = ctrl.Rule(taste['high']&environment['high']&budget['less preferred']&user_review['more preferred']&location['near'],preference['level3'])
rule225 = ctrl.Rule(taste['high']&environment['high']&budget['less preferred']&user_review['more preferred']&location['closer'],preference['level3'])
rule226 = ctrl.Rule(taste['high']&environment['high']&budget['preferred']&user_review['less preferred']&location['far'],preference['level3'])
rule227 = ctrl.Rule(taste['high']&environment['high']&budget['preferred']&user_review['less preferred']&location['near'],preference['level3'])
rule228 = ctrl.Rule(taste['high']&environment['high']&budget['preferred']&user_review['less preferred']&location['closer'],preference['level3'])
rule229 = ctrl.Rule(taste['high']&environment['high']&budget['preferred']&user_review['preferred']&location['far'],preference['level4'])
rule230 = ctrl.Rule(taste['high']&environment['high']&budget['preferred']&user_review['preferred']&location['near'],preference['level4'])
rule231 = ctrl.Rule(taste['high']&environment['high']&budget['preferred']&user_review['preferred']&location['closer'],preference['level4'])
rule232 = ctrl.Rule(taste['high']&environment['high']&budget['preferred']&user_review['more preferred']&location['far'],preference['level4'])
rule233 = ctrl.Rule(taste['high']&environment['high']&budget['preferred']&user_review['more preferred']&location['near'],preference['level4'])
rule234 = ctrl.Rule(taste['high']&environment['high']&budget['preferred']&user_review['more preferred']&location['closer'],preference['level4'])
rule235 = ctrl.Rule(taste['high']&environment['high']&budget['more preferred']&user_review['less preferred']&location['far'],preference['level4'])
rule236 = ctrl.Rule(taste['high']&environment['high']&budget['more preferred']&user_review['less preferred']&location['near'],preference['level4'])
rule237 = ctrl.Rule(taste['high']&environment['high']&budget['more preferred']&user_review['less preferred']&location['closer'],preference['level4'])
rule238= ctrl.Rule(taste['high']&environment['high']&budget['more preferred']&user_review['preferred']&location['far'],preference['level5'])
rule239 = ctrl.Rule(taste['high']&environment['high']&budget['more preferred']&user_review['preferred']&location['near'],preference['level5'])
rule240 = ctrl.Rule(taste['high']&environment['high']&budget['more preferred']&user_review['preferred']&location['closer'],preference['level5'])
rule241 = ctrl.Rule(taste['high']&environment['high']&budget['more preferred']&user_review['more preferred']&location['far'],preference['level5'])
rule242 = ctrl.Rule(taste['high']&environment['high']&budget['more preferred']&user_review['more preferred']&location['near'],preference['level5'])
rule243 = ctrl.Rule(taste['high']&environment['high']&budget['more preferred']&user_review['more preferred']&location['closer'],preference['level5'])

preferencing_ctrl = ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9,rule10,rule11,rule12,rule13,rule14,rule15,rule16,rule17,rule18,rule19,rule20,rule21,rule22,rule23,rule24,rule25,rule26,rule27,rule28,rule29,rule30,rule31,rule32,rule33,rule34,rule35,rule36,rule37,rule38,rule39,rule40,rule41,rule42,rule43,rule44,rule45,rule46,rule47,rule48,rule49,rule50,rule51,rule52,rule53,rule54,rule55,rule56,rule57,rule58,rule59,rule60,rule61,rule62,rule63,rule64,rule65,rule66,rule67,rule68,rule69,rule70,rule71,rule72,rule73,rule74,rule75,rule76,rule77,rule78,rule79,rule80,rule81,rule82,rule83,rule84,rule85,rule86,rule87,rule88,rule89,rule90,rule91,rule92,rule93,rule94,rule95,rule96,rule97,rule98,rule99,rule100,rule101,rule102,rule103,rule104,rule105,rule106,rule107,rule108,rule109,rule110,rule111,rule112,rule113,rule114,rule115,rule116,rule117,rule118,rule119,rule120,rule121,rule122,rule123,rule124,rule125,rule126,rule127,rule128,rule129,rule130,rule131,rule132,rule133,rule134,rule135,rule136,rule137,rule138,rule139,rule140,rule141,rule142,rule143,rule144,rule145,rule146,rule147,rule148,rule149,rule150,rule151,rule152,rule153,rule154,rule155,rule156,rule157,rule158,rule159,rule160,rule161,rule162,rule163,rule164,rule165,rule166,rule167,rule168,rule169,rule170,rule171,rule172,rule173,rule174,rule175,rule176,rule177,rule178,rule179,rule180,rule181,rule182,rule183,rule184,rule185,rule186,rule187,rule188,rule189,rule190,rule191,rule192,rule193,rule194,rule195,rule196,rule197,rule198,rule199,rule200,rule201,rule202,rule203,rule204,rule205,rule206,rule207,rule208,rule209,rule210,rule211,rule212,rule213,rule214,rule215,rule216,rule217,rule218,rule219,rule220,rule221,rule222,rule223,rule224,rule225,rule226,rule227,rule228,rule229,rule230,rule231,rule232,rule233,rule234,rule235,rule236,rule237,rule238,rule239,rule240,rule241,rule242,rule243])
preferencing=ctrl.ControlSystemSimulation(preferencing_ctrl)
preferencing.input['taste']=7
preferencing.input['environment']=7
preferencing.input['budget']=7
preferencing.input['user_review']=5
preferencing.input['location']=2
preferencing.compute()
print(preferencing.output['preference'])
preference.view(sim=preferencing)


taste.view()
environment.view()
budget.view()
user_review.view()
location.view()
preference.view()

     
4.323098740040626







1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e85deb9bbe82> in <module>
#       1 import numpy as np
# ----> 2 import skfuzzy as fuzz
#       3 from skfuzzy import control as ctrl
#       4
#       5
#
# ModuleNotFoundError: No module named 'skfuzzy'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
